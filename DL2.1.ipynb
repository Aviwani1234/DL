# %%
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
import random

# %%
mnist = tf.keras.datasets.mnist
(x_train, y_train), (x_test, y_test )= mnist.load_data()

# %%
x_train = x_train/255
x_test = x_test/255

# %%
model = keras.Sequential([
keras.layers.Flatten(input_shape=(28,28)),
keras.layers.Dense(128, activation="relu"),
keras.layers.Dense(10, activation="softmax")
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 128)               100480
#
#  dense_1 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 101770 (397.54 KB)
# Trainable params: 101770 (397.54 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(optimizer="sgd",
loss="sparse_categorical_crossentropy",
metrics=["accuracy"])

# %%
history=model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=11)
# Out:
# Epoch 1/11
# 1875/1875 [==============================] - 15s 7ms/step - loss: 0.6525 - accuracy: 0.8350 - val_loss: 0.3612 - val_accuracy: 0.9025
# Epoch 2/11
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.3388 - accuracy: 0.9058 - val_loss: 0.2940 - val_accuracy: 0.9170
# Epoch 3/11
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2905 - accuracy: 0.9186 - val_loss: 0.2637 - val_accuracy: 0.9254
# Epoch 4/11
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.2599 - accuracy: 0.9276 - val_loss: 0.2382 - val_accuracy: 0.9323
# Epoch 5/11
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2369 - accuracy: 0.9337 - val_loss: 0.2231 - val_accuracy: 0.9368
# Epoch 6/11
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.2181 - accuracy: 0.9389 - val_loss: 0.2055 - val_accuracy: 0.9424
# Epoch 7/11
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2025 - accuracy: 0.9438 - val_loss: 0.1947 - val_accuracy: 0.9445
# Epoch 8/11
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1894 - accuracy: 0.9472 - val_loss: 0.1849 - val_accuracy: 0.9482
# Epoch 9/11
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1778 - accuracy: 0.9499 - val_loss: 0.1731 - val_accuracy: 0.9511
# Epoch 10/11
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1675 - accuracy: 0.9529 - val_loss: 0.1652 - val_accuracy: 0.9529
# Epoch 11/11
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1584 - accuracy: 0.9556 - val_loss: 0.1581 - val_accuracy: 0.9551

# %%
test_loss, test_acc=model.evaluate(x_test, y_test)
print("Loss=%.3f" %test_loss)
print("Accuracy=%.3f" %test_acc)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1581 - accuracy: 0.9551
# Loss=0.158
# Accuracy=0.955

# %%
n=random.randint(0,9999)
plt.imshow(x_test[n])
plt.show()
predicted_value=model.predict(x_test)
plt.imshow(x_test[n])
plt.show()
# Out:
# 313/313 [==============================] - 1s 2ms/step

# %%
print('Predicted Value: ', predicted_value[n])
# Out:
# Predicted Value:  [2.0076375e-01 4.0690379e-06 2.3475274e-02 6.9803506e-01 1.8446408e-09
#  7.1752042e-02 3.0768990e-07 1.8509339e-03 3.8356814e-03 2.8282029e-04]

# %%
plt.plot(history.history["accuracy"])
plt.plot(history.history["val_accuracy"])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='center right')
plt.show()

# %%
plt.plot(history.history["loss"])
plt.plot(history.history["val_loss"])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='center right')
plt.show()
